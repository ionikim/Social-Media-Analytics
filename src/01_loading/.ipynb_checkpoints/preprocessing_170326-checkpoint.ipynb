# %% [markdown]
# <a href="https://colab.research.google.com/github/ionikim/epilepsy_pediatrics_EEG/blob/main/src/01_loading/preprocessing_150326.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Following marina's file, here I preprocessed another EEG recording from the same patient during seizure onset (for file chb01_15, and seizure annotated on the chb01_15.seizure file)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-87c6745f-2037-41be-b091-e33b14950946" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87c6745f-2037-41be-b091-e33b14950946">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# libraries for the preprocessing
# !pip install mne
import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.listdir()
# Out:
# ['.config',
#  'chb01_15 (2).edf',
#  'chb01_15.edf',
#  'chb01_15 (1).edf',
#  'chb01_15.edf.seizures.seizures',
#  'sample_data']

# %% [markdown]
# 01. Loading Data
#
#     01-1. Loading EEG data

# %%
# Load Data

raw_15 = mne.io.read_raw_edf('chb01_15.edf', preload=True)

# raw signal array load
raw_data_15 = raw_15.get_data()

# test
print("Number of channels:", raw_data_15.shape[0])
print("Number of samples:", raw_data_15.shape[1])

plt.plot(raw_data_15[0, :300])
plt.title("Raw EEG, electrode 0, samples 0-299")
plt.xlabel("Sample")
plt.ylabel("Amplitude")
plt.show()
# Out:
# Extracting EDF parameters from chb01_15.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# /tmp/ipykernel_1140/1646767560.py:3: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw_15 = mne.io.read_raw_edf('chb01_15.edf', preload=True)
# Number of channels: 23
# Number of samples: 921600

# %% [markdown]
# 01-2. loading seizure annotation

# %%
def get_seizure_period(annotation_file):

    with open(annotation_file, "rb") as f:
        byte_array = f.read()

    start = int(bin(byte_array[38])[2:] + bin(byte_array[41])[2:], 2)
    length = byte_array[49]

    return start, length

# %%
start, length = get_seizure_period("chb01_15.edf.seizures.seizures")

print("Seizure start:", start)
print("Seizure length:", length)
print("Seizure end:", start + length)
# Out:
# Seizure start: 1732
# Seizure length: 40
# Seizure end: 1772

# %% [markdown]
# 02.Filtering

# %%
# filtering

# 1. Band-pass filtering
filtered_raw_15 = raw_15.copy().filter(l_freq=1.0, h_freq=45.0)

# 2. psd(power spectral density) before filtering
psd_before = raw_15.compute_psd(fmax=60)
fig_before = psd_before.plot(show=False)
plt.title("PSD Before Filtering (0-60 Hz)")
plt.show()

#3. psd after filtering
psd_after = filtered_raw_15.compute_psd(fmax=60)
psd_after.plot(show=False)
plt.title("PSD After Filtering (0-60 Hz)")
plt.show()
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Effective window size : 8.000 (s)
# Plotting power spectral density (dB=True).
# /tmp/ipykernel_1140/637441708.py:8: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   fig_before = psd_before.plot(show=False)
# <MNELineFigure size 1000x350 with 1 Axes>
# Effective window size : 8.000 (s)
# Plotting power spectral density (dB=True).
# ...

# %% [markdown]
# 03.re-referencing data

# %%
# re-referencing data
processed_raw = filtered_raw_15.copy()
processed_raw.set_eeg_reference('average')

# Visualization
processed_raw.plot(start=60, duration=5)
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# 04. creating an array

# %%
# get electrode names
electrode_names = processed_raw.ch_names

# get sampling frequency
sfreq = processed_raw.info['sfreq']

# calculate time points in seconds
n_samples = len(processed_raw.times)
time_marks = np.arange(n_samples) / sfreq

# electrode data
electrode_data = processed_raw.get_data()

# create DataFrame
df = pd.DataFrame(electrode_data.T, columns=electrode_names)

# time as index
df.index = time_marks
df.index.name = 'Time (s)'

display(df.head())
# Out:
#                 FP1-F7         F7-T7         T7-P7         P7-O1  \
# Time (s)
# 0.000000 -5.745093e-21 -4.640267e-20  1.458370e-20 -5.745093e-21
# 0.003906  5.720228e-05  1.334602e-04  1.075441e-05 -1.003093e-04
# 0.007812  8.927366e-05  2.099841e-04  1.713179e-05 -1.563617e-04
# 0.011719  9.148235e-05  2.184314e-04  1.844967e-05 -1.591412e-04
# 0.015625  7.989256e-05  1.938156e-04  1.732321e-05 -1.366113e-04
#
#                 FP1-F3         F3-C3         C3-P3         P3-O1  \
# Time (s)
# 0.000000 -1.252136e-20 -5.995520e-20 -5.745093e-21  2.135996e-20
# 0.003906  7.186760e-05  7.021685e-05  3.779674e-06 -4.473565e-05
# 0.007812  1.127198e-04  1.104094e-04  5.634313e-06 -6.858901e-05
# 0.011719  1.166468e-04  1.145705e-04  5.813522e-06 -6.750578e-05
# 0.015625  1.030342e-04  1.011703e-04  5.969361e-06 -5.544932e-05
#
#                 FP2-F4         F4-C4  ...         F8-T8       T8-P8-0  \
# Time (s)                              ...
# ...

# %% [markdown]
# 05. segmenting into 5 second windows
#
#     05-1. Segmentation

# %%
window_size = 5  # seconds

# assign window number to each time sample
df['window'] = (df.index // window_size).astype(int)

# group data by window
df_windows = df.drop(columns='window').groupby(df['window']).agg(list)

# check result
display(df_windows.head())
print("Shape:", df_windows.shape)
# Out:
#                                                    FP1-F7  \
# window
# 0       [-5.745093033550908e-21, 5.7202276825605535e-0...
# 1       [-1.1545715625185255e-06, 3.562830648988419e-0...
# 2       [1.3513672456593916e-05, 1.0820931297801697e-0...
# 3       [-3.4659213586294126e-05, -3.14146738778134e-0...
# 4       [-3.4073396382604735e-05, -3.0358374270560778e...
#
#                                                     F7-T7  \
# window
# 0       [-4.640267450175732e-20, 0.0001334601954958965...
# 1       [4.97576845296956e-05, 5.0224725372398397e-05,...
# 2       [-1.6810274739001806e-05, -1.1439913612990415e...
# 3       [1.5765785881829257e-05, 2.2475078958081414e-0...
# 4       [8.941064377544184e-08, 5.344334864234166e-06,...
#
#                                                     T7-P7  \
# window
# 0       [1.45836977005523e-20, 1.0754409504594879e-05,...
# 1       [4.334342942325463e-05, 4.147452921179149e-05,...
# 2       [-1.4740159525394516e-05, -1.2045785195330215e...
# ...

# %% [markdown]
# 05-02. Seizuer Labeling

# %%
# seizure information
seizure_start = 1732
seizure_end = 1772

labels = []

for window in df_windows.index:
    window_start = window * window_size
    window_end = window_start + window_size

    # check if window overlaps seizure period
    if (window_start < seizure_end) and (window_end > seizure_start):
        labels.append("ictal")
    else:
        labels.append("interictal")

# add label column
df_windows["label"] = labels

# check labels
print(df_windows["label"].value_counts())
display(df_windows.head())
# Out:
# label
# interictal    711
# ictal           9
# Name: count, dtype: int64
#                                                    FP1-F7  \
# window
# 0       [-5.745093033550908e-21, 5.7202276825605535e-0...
# 1       [-1.1545715625185255e-06, 3.562830648988419e-0...
# 2       [1.3513672456593916e-05, 1.0820931297801697e-0...
# 3       [-3.4659213586294126e-05, -3.14146738778134e-0...
# 4       [-3.4073396382604735e-05, -3.0358374270560778e...
#
#                                                     F7-T7  \
# window
# 0       [-4.640267450175732e-20, 0.0001334601954958965...
# 1       [4.97576845296956e-05, 5.0224725372398397e-05,...
# 2       [-1.6810274739001806e-05, -1.1439913612990415e...
# 3       [1.5765785881829257e-05, 2.2475078958081414e-0...
# 4       [8.941064377544184e-08, 5.344334864234166e-06,...
#
#                                                     T7-P7  \
# window
# 0       [1.45836977005523e-20, 1.0754409504594879e-05,...
# ...

# %%
# check the result of labeling

print(df_windows["label"].value_counts())
print(df_windows[df_windows["label"] == "ictal"].index)

plt.figure(figsize=(12,4))

plt.plot(df.index, df["FP1-F7"])

plt.axvspan(seizure_start, seizure_end, color='red', alpha=0.3)

plt.xlabel("Time (seconds)")
plt.ylabel("Amplitude")
plt.title("EEG signal with seizure interval")

plt.show()
# Out:
# label
# interictal    711
# ictal           9
# Name: count, dtype: int64
# Index([346, 347, 348, 349, 350, 351, 352, 353, 354], dtype='int64', name='window')

# %% [markdown]
# 06. Calculating power of 5-second windows

# %%
signal_columns = [col for col in df_windows.columns if col != "label"]

window_power_rows = []

for window in df_windows.index:
    row = {}

    for electrode in signal_columns:
        window_values = df_windows.loc[window, electrode]
        row[electrode] = np.mean(np.array(window_values) ** 2)

    row["label"] = df_windows.loc[window, "label"]
    window_power_rows.append(row)

window_powers_df = pd.DataFrame(window_power_rows, index=df_windows.index)
window_powers_df.index.name = "window"

display(window_powers_df.head())
print(window_powers_df.shape)
# Out:
#               FP1-F7         F7-T7         T7-P7         P7-O1        FP1-F3  \
# window
# 0       3.523664e-09  2.842651e-09  1.220028e-09  3.512421e-09  4.131679e-09
# 1       2.972456e-09  1.273183e-09  2.006125e-09  1.737941e-09  4.939364e-09
# 2       3.007028e-09  6.576429e-10  1.006253e-09  1.889292e-09  4.363369e-09
# 3       1.176249e-09  8.376111e-10  1.211691e-09  1.181409e-09  2.439798e-09
# 4       2.561193e-09  1.398609e-09  1.823071e-09  2.067982e-09  5.039648e-09
#
#                F3-C3         C3-P3         P3-O1        FP2-F4         F4-C4  \
# window
# 0       2.282510e-09  7.516497e-10  5.047017e-09  3.812045e-09  2.335722e-09
# 1       2.966180e-09  8.857755e-10  2.574509e-09  2.977757e-09  3.705319e-09
# 2       1.628035e-09  1.070903e-09  4.022928e-09  4.786915e-09  2.533385e-09
# 3       1.950216e-09  1.336029e-09  2.821976e-09  3.582315e-09  2.534780e-09
# 4       2.949983e-09  1.562829e-09  5.776245e-09  5.278999e-09  4.000790e-09
#
# ...

# %% [markdown]
# 07. Check the ictal windows

# %%
ictal_df = window_powers_df[window_powers_df["label"] == "ictal"]
interictal_df = window_powers_df[window_powers_df["label"] == "interictal"]

print("ictal windows:", len(ictal_df))
print("interictal windows:", len(interictal_df))

display(ictal_df.head())
# Out:
# ictal windows: 9
# interictal windows: 711
#               FP1-F7         F7-T7         T7-P7         P7-O1        FP1-F3  \
# window
# 346     3.091744e-09  1.055718e-09  1.814008e-09  1.290928e-09  7.030047e-09
# 347     7.272367e-09  2.672538e-09  1.903325e-09  1.978780e-09  1.698301e-08
# 348     3.016523e-09  5.620176e-09  3.743610e-09  5.234986e-09  6.119362e-09
# 349     4.750194e-09  6.417138e-09  5.798161e-09  9.022540e-09  8.541836e-09
# 350     7.170654e-09  6.693418e-09  5.390137e-09  1.123345e-08  1.188352e-08
#
#                F3-C3         C3-P3         P3-O1        FP2-F4         F4-C4  \
# window
# 346     1.972383e-09  1.038861e-09  2.435549e-09  7.707478e-09  4.114839e-09
# 347     3.087871e-09  2.400343e-09  6.998672e-09  1.142316e-08  9.023751e-09
# 348     3.657389e-09  2.019719e-09  4.208810e-09  6.592919e-09  5.223147e-09
# 349     5.015836e-09  3.730876e-09  9.134650e-09  6.439519e-09  3.363953e-09
# ...

# %%
print(df_windows[df_windows["label"] == "ictal"].index.tolist())
# Out:
# [346, 347, 348, 349, 350, 351, 352, 353, 354]

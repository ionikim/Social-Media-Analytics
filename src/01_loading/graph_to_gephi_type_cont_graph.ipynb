# %% [markdown]
# <a href="https://colab.research.google.com/github/ionikim/epilepsy_pediatrics_EEG/blob/main/src/01_loading/graph_to_gephi_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pathlib import Path
# %cd "C:\Users\marin\OneDrive\Dokumente\Uni\MSc_DNs_Fribourg\FS26\Social_Media_Analytics\git"
# Out:
# C:\Users\marin\OneDrive\Dokumente\Uni\MSc_DNs_Fribourg\FS26\Social_Media_Analytics\git

# %%
edge_list = pd.read_csv(
    "data/graphs/edges/inter_to_ict_chb01_03_2980_3010_edges.csv"
)

node_table = pd.read_csv(
    "data/graphs/nodes/inter_to_ict_chb01_03_2980_3010_nodes.csv"
)

print(edge_list.shape)
print(node_table.shape)

display(edge_list.head())
display(node_table.head())
# Out:
# (1978201, 7)
# (176640, 6)
#          Source        Target  source_label  target_label edge_type   layer  \
# 0  FP1-F7_t7436  FP1-F7_t7437  FP1-F7_t7436  FP1-F7_t7437     intra  FP1-F7
# 1  FP1-F7_t7295  FP1-F7_t7437  FP1-F7_t7295  FP1-F7_t7437     intra  FP1-F7
# 2  FP1-F7_t7289  FP1-F7_t7437  FP1-F7_t7289  FP1-F7_t7437     intra  FP1-F7
# 3  FP1-F7_t7288  FP1-F7_t7437  FP1-F7_t7288  FP1-F7_t7437     intra  FP1-F7
# 4  FP1-F7_t7056  FP1-F7_t7437  FP1-F7_t7056  FP1-F7_t7437     intra  FP1-F7
#
#      weight
# 0  0.000035
# 1  0.000033
# 2  0.000022
# 3  0.000016
# 4  0.000015
#           Id      Label electrode  time_idx   layer graph_label
# 0  FP1-F7_t0  FP1-F7_t0    FP1-F7         0  FP1-F7       ictal
# 1  FP1-F7_t1  FP1-F7_t1    FP1-F7         1  FP1-F7       ictal
# 2  FP1-F7_t2  FP1-F7_t2    FP1-F7         2  FP1-F7       ictal
# 3  FP1-F7_t3  FP1-F7_t3    FP1-F7         3  FP1-F7       ictal
# 4  FP1-F7_t4  FP1-F7_t4    FP1-F7         4  FP1-F7       ictal

# %%
def export_to_gephi(edge_list, node_table, graph_id, out_dir="data/gephi", max_edges=None):
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    # ----- Edges -----
    gephi_edges = edge_list.copy()

    gephi_edges = gephi_edges.rename(columns={
        "source": "Source",
        "target": "Target"
    })

    # Gephi edge type : undirected
    gephi_edges["Type"] = "Undirected"

    # when we don't have weight, it will assign 1.0
    if "weight" in gephi_edges.columns:
        gephi_edges = gephi_edges.rename(columns={"weight": "Weight"})
    else:
        gephi_edges["Weight"] = 1.0

    # edge type store
    if "edge_type" in gephi_edges.columns:
        gephi_edges["edge_type"] = gephi_edges["edge_type"]

    # when it's too big, keep the part of it
    if max_edges is not None and len(gephi_edges) > max_edges:
        gephi_edges = gephi_edges.sample(n=max_edges, random_state=42)

    edge_cols = ["Source", "Target", "Type", "Weight"]
    extra_edge_cols = [c for c in ["edge_type", "layer", "source_label", "target_label"] if c in gephi_edges.columns]
    edge_cols += extra_edge_cols

    edge_path = out_dir / f"{graph_id}_edges.csv"
    gephi_edges[edge_cols].to_csv(edge_path, index=False)

    # ----- Nodes -----
    gephi_nodes = node_table.copy()

    gephi_nodes = gephi_nodes.rename(columns={
        "node_id": "Id",
        "node_label": "Label"
    })

    node_cols = ["Id", "Label"]
    extra_node_cols = [c for c in ["electrode", "time_idx", "time_s"] if c in gephi_nodes.columns]
    node_cols += extra_node_cols

    node_path = out_dir / f"{graph_id}_nodes.csv"
    gephi_nodes[node_cols].to_csv(node_path, index=False)

    print(f"Saved Gephi edges: {edge_path}")
    print(f"Saved Gephi nodes: {node_path}")

    return edge_path, node_path

# %%
export_to_gephi(
    edge_list=edge_list,
    node_table=node_table,
    graph_id="chb01_03_inter_to_ictal",
    out_dir="data/gephi"
)
# Out:
# Saved Gephi edges: data\gephi\chb01_03_inter_to_ictal_edges.csv
# Saved Gephi nodes: data\gephi\chb01_03_inter_to_ictal_nodes.csv
# (WindowsPath('data/gephi/chb01_03_inter_to_ictal_edges.csv'),
#  WindowsPath('data/gephi/chb01_03_inter_to_ictal_nodes.csv'))

# %%
export_to_gephi(
    edge_list=edge_list,
    node_table=node_table,
    graph_id="chb01_03_inter_to_ictal_small",
    out_dir="data/gephi",
    max_edges=5000
)
# Out:
# Saved Gephi edges: data\gephi\chb01_03_inter_to_ictal_small_edges.csv
# Saved Gephi nodes: data\gephi\chb01_03_inter_to_ictal_small_nodes.csv
# (WindowsPath('data/gephi/chb01_03_inter_to_ictal_small_edges.csv'),
#  WindowsPath('data/gephi/chb01_03_inter_to_ictal_small_nodes.csv'))
